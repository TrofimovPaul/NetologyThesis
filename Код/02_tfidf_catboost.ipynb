# %% [markdown]
# # Импорты

# %%
# импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib # модуль для сохранения и открытия моделей
import sklearn
import os
import time

from catboost import CatBoostClassifier, Pool

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, multilabel_confusion_matrix, ConfusionMatrixDisplay

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## Загрузка обучающего и тестового датасетов

# %%
df_train = pd.read_csv('..\\Датасеты\\news_train.csv')
df_test = pd.read_csv('..\\Датасеты\\news_test.csv')

X_train, y_train = df_train['text_lemma'], df_train.drop('text_lemma', axis=1)
X_test, y_test = df_test['text_lemma'], df_test.drop('text_lemma', axis=1)

# %% [markdown]
# ## Метрики

# %%
def identity(y_test, y_pred):
    '''
    Расчёт похожести объектов через расстояние Хэмминга

    y_test - тестовые целевые данные

    y_pred - предсказанные целевые данные

    Вывод среднего значения похожести объектов по всем элементам 

    '''
    y_true = y_test.to_numpy()

    if (len(y_true) != len(y_pred)):

        raise Exception('Объекты должны быть одинаковой длины')
    identity_list = []
    for elem in range(len(y_true)):
        #print('true:', y_true[elem])
        #print('pred:', y_pred[elem])
        #print(len(y_true[elem]) == len(y_pred[elem]))
        #print(len(y_test[elem]))
        if (len(y_true[elem]) != len(y_pred[elem])):

            raise Exception('Элементы должны быть одинаковой длины')
        # Инициализация переменной расстояния Хэмминга
        dist_counter = 0
        for n in range(len(y_true[elem])):
            # Изменение расстояния Хэмминга при наличии разницы между объектами
            if y_true[elem][n] != y_pred[elem][n]:
                
                dist_counter += 1
                
        len_elem = len(y_true[elem])
        # Расчёт доли похожести элементов двух объектов через Расстояние Хэмминга(dist_counter/len_elem - доля непохожести двух объектов)
        identity = round(1 - dist_counter/len_elem, 3)
        identity_list.append(identity)

    return round(np.mean(identity_list),5)

# %%
def hamming_distance(y_test, y_pred):
    '''
    Расчёт доработанного расстояния Хэмминга с ориентацией на целевое значение = 1

    y_test - тестовые целевые данные

    y_pred - предсказанные целевые данные

    Вывод среднего значения расстояния Хэмминга по всем элементам 

    '''
    y_true = y_test.to_numpy()

    if (len(y_true) != len(y_pred)):
        raise Exception('Объекты должны быть одинаковой длины')
    distance_list = []
    
    for elem in range(len(y_true)):
        if (len(y_true[elem]) != len(y_pred[elem])):
            raise Exception('Элементы должны быть одинаковой длины')

        indices_1_y_true = set(np.where(y_true[elem])[0])
        indices_1_y_pred = set(np.where(y_pred[elem])[0])
        
        if len(indices_1_y_true) == 0 and len(indices_1_y_pred) == 0:
            dist_counter = 1

        else:
            dist_counter = len(indices_1_y_true.intersection(indices_1_y_pred)) / float(len(indices_1_y_true.union(indices_1_y_pred)))

        distance_list.append(dist_counter)
    return round(np.mean(distance_list),5)

# %%
def estimation(y_test, y_pred, save_file=False, filename='filename'):
    '''
    Вывод результирующих метрик
    '''
    
    columns = y_test.columns
    y_true = y_test.to_numpy()
    print('Accuracy:', round(accuracy_score(y_true, y_pred), 5))
    print('Hamming distance:', hamming_distance(y_test, y_pred))
    print('Identity (by Hamming distance):', identity(y_test, y_pred), '\n')
    print(classification_report(y_true, y_pred, target_names=columns, zero_division=0))
    
    if save_file is True:
        np.savetxt(filename, y_pred.astype(int), fmt='%i', delimiter=',')

# %%
def cm_show(y_test, y_pred, nrows=10, ncols=5, figsize_w=30, figsize_h=60, wspace=0.2, hspace=0.4):
    '''
    Вывод матрицы несоответствия для каждой тематической категории в формате:   
    
    [['TN', 'FP'],
     ['FN', 'TP']]

    y_test - тестовые целевые данные

    y_pred - предсказанные целевые данные

    nrows - количество строк в сетке матриц несоответствия (для корректного отображения сетки должно
    работать уравнение: nrows = figsize_h / 6)

    ncols - количество столбцов в сетке матриц несоответствия (для корректного отображения сетки должно
    работать уравнение: ncols = figsize_w / 6)

    figsize_w - ширина полотна для вывода сетки матриц несоответствия (для корректного отображения сетки должно
    работать уравнение: figsize_h = 6 * ncols)

    figsize_h - высота полотна для вывода сетки матриц несоответствия (для корректного отображения сетки должно
    работать уравнение: figsize_h = 6 * nrows)

    wspace - расстояние по ширине между отдельными ячейками сетки матриц несоответствия

    hspace - расстояние по высоте между отдельными ячейками сетки матриц несоответствия
    '''
    
    start = time.time()
    y_true = y_test.to_numpy()
    axis = plt.subplots(nrows, ncols, figsize=(figsize_w, figsize_h))[1]
    axis = axis.ravel()
    
    # обычная матрица несоответствий
    # actual = np.array(y_true).T
    # predicted = np.array(y_pred).T
    
    # for tag_num in range(len(y_test.columns)):
    #    cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix(actual[tag_num], predicted[tag_num]),
    #                                        display_labels = [0,1])
    #    cm_display.plot(ax=axis[tag_num],cmap=plt.cm.GnBu)
    #    cm_display.ax_.set_title(f'{y_test.columns[tag_num]}')
    
    # многоклассовая матрица несоответствий
    mlcm = multilabel_confusion_matrix(y_true, y_pred)
        
    for tag_num in range(len(y_test.columns)):
    #    Если надо отобразить количество
    #    mlcm_display = ConfusionMatrixDisplay(confusion_matrix = mlcm[i], display_labels = [0,1]) 
    #    mlcm_display.plot(ax=axis[tag_num],cmap=plt.cm.GnBu)
    #    mlcm_display.ax_.set_title(f'{y_test.columns[tag_num]}') 

    #   Если надо отобразить проценты. 
    #   Так как в рамках задачи наибольший интерес вызывает информация о точном предсказании (y_true = 1, y_pred = 1)
    #   или о грубой ошибке при предсказании (y_true = 1, y_pred = 0) категории, имеет смысл выводить информацию для
    #   дальнейшего анализа в виде доли верных и неверных предсказаний для целевого значения = 1. 
        mlcm_percent = mlcm[tag_num] / mlcm[tag_num].sum(axis=1).reshape(2, -1)
        
        true0_row = mlcm[tag_num].sum(axis=1)[0] # количество TN, FP предсказаний (нецелевое значение = 0)
        true1_row = mlcm[tag_num].sum(axis=1)[1] # количество TP, FN предсказаний (целевое значение = 1)
        
        mlcm_percent_display = ConfusionMatrixDisplay(mlcm_percent, display_labels=[0, 1])        
        mlcm_percent_display.plot(ax=axis[tag_num],cmap=plt.cm.GnBu, values_format="0.3f")
        mlcm_percent_display.ax_.set_title(f'{y_test.columns[tag_num]} (TL0: {true0_row}, TL1:{true1_row})') 

    plt.subplots_adjust(wspace=wspace, hspace=hspace)
    plt.show()
    return print(f'Время выполнения: {round(time.time() - start,3)} с')

# %% [markdown]
# # Модель на униграммах

# %% [markdown]
# ## Структура

# %%
# %%time
pipe = Pipeline([('tfidf', TfidfVectorizer(analyzer='word',ngram_range=(1, 1))),('catboost', MultiOutputClassifier(estimator=CatBoostClassifier(task_type='CPU',iterations=100,verbose=True,random_state=42,))),])
pipe.fit(X_train,y_train,catboost__verbose=50)
# Out:
# Learning rate set to 0.477254
# 0:	learn: 0.1520794	total: 936ms	remaining: 1m 32s
# 50:	learn: 0.0124645	total: 38.8s	remaining: 37.3s
# 99:	learn: 0.0075347	total: 1m 15s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0555476	total: 772ms	remaining: 1m 16s
# 50:	learn: 0.0000865	total: 38.5s	remaining: 37s
# 99:	learn: 0.0000517	total: 1m 15s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0834272	total: 775ms	remaining: 1m 16s
# 50:	learn: 0.0020954	total: 38.6s	remaining: 37.1s
# 99:	learn: 0.0008411	total: 1m 15s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0870175	total: 783ms	remaining: 1m 17s
# 50:	learn: 0.0043564	total: 38.7s	remaining: 37.2s
# 99:	learn: 0.0022593	total: 1m 15s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521216	total: 809ms	remaining: 1m 20s
# 50:	learn: 0.0225177	total: 38.9s	remaining: 37.4s
# 99:	learn: 0.0157037	total: 1m 15s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0633951	total: 801ms	remaining: 1m 19s
# 50:	learn: 0.0006849	total: 39.3s	remaining: 37.7s
# 99:	learn: 0.0003633	total: 1m 16s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522629	total: 787ms	remaining: 1m 17s
# 50:	learn: 0.0141891	total: 39.3s	remaining: 37.8s
# 99:	learn: 0.0090648	total: 1m 16s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0979725	total: 810ms	remaining: 1m 20s
# 50:	learn: 0.0149621	total: 39.6s	remaining: 38s
# 99:	learn: 0.0092311	total: 1m 17s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1038687	total: 791ms	remaining: 1m 18s
# 50:	learn: 0.0049175	total: 39.4s	remaining: 37.8s
# 99:	learn: 0.0026947	total: 1m 17s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0347960	total: 788ms	remaining: 1m 18s
# 50:	learn: 0.0001970	total: 39.3s	remaining: 37.8s
# 99:	learn: 0.0000741	total: 1m 17s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1293274	total: 801ms	remaining: 1m 19s
# 50:	learn: 0.0055069	total: 39.4s	remaining: 37.8s
# 99:	learn: 0.0023608	total: 1m 16s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1517721	total: 788ms	remaining: 1m 18s
# 50:	learn: 0.0132421	total: 39.5s	remaining: 38s
# 99:	learn: 0.0082802	total: 1m 17s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1508557	total: 806ms	remaining: 1m 19s
# 50:	learn: 0.0241281	total: 39.7s	remaining: 38.1s
# 99:	learn: 0.0172781	total: 1m 17s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520112	total: 816ms	remaining: 1m 20s
# 50:	learn: 0.0223135	total: 39.9s	remaining: 38.3s
# 99:	learn: 0.0154621	total: 1m 19s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521057	total: 941ms	remaining: 1m 33s
# 50:	learn: 0.0167008	total: 41.2s	remaining: 39.5s
# 99:	learn: 0.0114805	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1383135	total: 809ms	remaining: 1m 20s
# 50:	learn: 0.0052504	total: 40.1s	remaining: 38.5s
# 99:	learn: 0.0022503	total: 1m 18s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1516783	total: 795ms	remaining: 1m 18s
# 50:	learn: 0.0293400	total: 39.9s	remaining: 38.3s
# 99:	learn: 0.0202896	total: 1m 18s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1518882	total: 836ms	remaining: 1m 22s
# 50:	learn: 0.0190316	total: 39.8s	remaining: 38.2s
# 99:	learn: 0.0127955	total: 1m 17s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1508904	total: 808ms	remaining: 1m 19s
# 50:	learn: 0.0160288	total: 39.9s	remaining: 38.3s
# 99:	learn: 0.0101163	total: 1m 18s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1272038	total: 816ms	remaining: 1m 20s
# 50:	learn: 0.0181832	total: 41.3s	remaining: 39.7s
# 99:	learn: 0.0114445	total: 1m 19s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1020649	total: 812ms	remaining: 1m 20s
# 50:	learn: 0.0079824	total: 40.2s	remaining: 38.6s
# 99:	learn: 0.0039447	total: 1m 19s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0857807	total: 811ms	remaining: 1m 20s
# 50:	learn: 0.0015573	total: 40.2s	remaining: 38.6s
# 99:	learn: 0.0005565	total: 1m 18s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1523098	total: 837ms	remaining: 1m 22s
# 50:	learn: 0.0043704	total: 40.7s	remaining: 39.1s
# 99:	learn: 0.0020355	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0946672	total: 839ms	remaining: 1m 23s
# 50:	learn: 0.0120970	total: 41.7s	remaining: 40.1s
# 99:	learn: 0.0067399	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1355689	total: 838ms	remaining: 1m 23s
# 50:	learn: 0.0020433	total: 41.1s	remaining: 39.5s
# 99:	learn: 0.0007652	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1217784	total: 822ms	remaining: 1m 21s
# 50:	learn: 0.0006840	total: 41.2s	remaining: 39.6s
# 99:	learn: 0.0002922	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1260768	total: 811ms	remaining: 1m 20s
# 50:	learn: 0.0213138	total: 40.3s	remaining: 38.7s
# 99:	learn: 0.0145354	total: 1m 18s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1256706	total: 854ms	remaining: 1m 24s
# 50:	learn: 0.0113095	total: 40.4s	remaining: 38.8s
# 99:	learn: 0.0067366	total: 1m 19s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521621	total: 823ms	remaining: 1m 21s
# 50:	learn: 0.0191131	total: 41.4s	remaining: 39.8s
# 99:	learn: 0.0131087	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520327	total: 835ms	remaining: 1m 22s
# 50:	learn: 0.0152019	total: 41.6s	remaining: 40s
# 99:	learn: 0.0098041	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1517460	total: 837ms	remaining: 1m 22s
# 50:	learn: 0.0113937	total: 42s	remaining: 40.4s
# 99:	learn: 0.0068486	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0885126	total: 876ms	remaining: 1m 26s
# 50:	learn: 0.0035945	total: 41.5s	remaining: 39.9s
# 99:	learn: 0.0016626	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1514382	total: 818ms	remaining: 1m 21s
# 50:	learn: 0.0183751	total: 41.7s	remaining: 40.1s
# 99:	learn: 0.0122508	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0610215	total: 865ms	remaining: 1m 25s
# 50:	learn: 0.0007611	total: 42.1s	remaining: 40.4s
# 99:	learn: 0.0003019	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0883892	total: 847ms	remaining: 1m 23s
# 50:	learn: 0.0074088	total: 41.3s	remaining: 39.7s
# 99:	learn: 0.0038184	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1181094	total: 826ms	remaining: 1m 21s
# 50:	learn: 0.0092029	total: 41.4s	remaining: 39.8s
# 99:	learn: 0.0052384	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1140368	total: 858ms	remaining: 1m 24s
# 50:	learn: 0.0061910	total: 40.6s	remaining: 39s
# 99:	learn: 0.0031962	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1519620	total: 853ms	remaining: 1m 24s
# 50:	learn: 0.0083299	total: 41.8s	remaining: 40.2s
# 99:	learn: 0.0041536	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522397	total: 822ms	remaining: 1m 21s
# 50:	learn: 0.0203153	total: 41.3s	remaining: 39.6s
# 99:	learn: 0.0146765	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1236704	total: 855ms	remaining: 1m 24s
# 50:	learn: 0.0044473	total: 42.1s	remaining: 40.5s
# 99:	learn: 0.0021819	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522323	total: 935ms	remaining: 1m 32s
# 50:	learn: 0.0205104	total: 43.6s	remaining: 41.9s
# 99:	learn: 0.0129729	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522062	total: 867ms	remaining: 1m 25s
# 50:	learn: 0.0038139	total: 42.5s	remaining: 40.8s
# 99:	learn: 0.0017036	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1514831	total: 843ms	remaining: 1m 23s
# 50:	learn: 0.0342017	total: 42.2s	remaining: 40.5s
# 99:	learn: 0.0245244	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1043115	total: 879ms	remaining: 1m 26s
# 50:	learn: 0.0076173	total: 41.9s	remaining: 40.3s
# 99:	learn: 0.0039361	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520682	total: 830ms	remaining: 1m 22s
# 50:	learn: 0.0354291	total: 42.1s	remaining: 40.5s
# 99:	learn: 0.0249645	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1386457	total: 835ms	remaining: 1m 22s
# 50:	learn: 0.0217921	total: 43s	remaining: 41.3s
# 99:	learn: 0.0151548	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1186050	total: 813ms	remaining: 1m 20s
# 50:	learn: 0.0074858	total: 41.6s	remaining: 40s
# 99:	learn: 0.0039428	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0340869	total: 887ms	remaining: 1m 27s
# 50:	learn: 0.0004265	total: 42.8s	remaining: 41.2s
# 99:	learn: 0.0001722	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1518284	total: 876ms	remaining: 1m 26s
# 50:	learn: 0.0198807	total: 42.1s	remaining: 40.4s
# 99:	learn: 0.0133986	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1026404	total: 804ms	remaining: 1m 19s
# 50:	learn: 0.0058369	total: 41.2s	remaining: 39.6s
# 99:	learn: 0.0030701	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1519597	total: 832ms	remaining: 1m 22s
# 50:	learn: 0.0112088	total: 41.6s	remaining: 40s
# 99:	learn: 0.0068656	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520953	total: 808ms	remaining: 1m 19s
# 50:	learn: 0.0262038	total: 42.2s	remaining: 40.5s
# 99:	learn: 0.0177135	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520700	total: 841ms	remaining: 1m 23s
# 50:	learn: 0.0373588	total: 42.1s	remaining: 40.4s
# 99:	learn: 0.0270317	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520858	total: 829ms	remaining: 1m 22s
# 50:	learn: 0.0094595	total: 41.1s	remaining: 39.5s
# 99:	learn: 0.0052006	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1336047	total: 829ms	remaining: 1m 22s
# 50:	learn: 0.0173986	total: 41.3s	remaining: 39.6s
# 99:	learn: 0.0116918	total: 1m 20s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0383176	total: 848ms	remaining: 1m 23s
# 50:	learn: 0.0001644	total: 41.8s	remaining: 40.2s
# 99:	learn: 0.0000593	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1523024	total: 864ms	remaining: 1m 25s
# 50:	learn: 0.0231393	total: 42.3s	remaining: 40.6s
# 99:	learn: 0.0146927	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521632	total: 902ms	remaining: 1m 29s
# 50:	learn: 0.0213710	total: 42.1s	remaining: 40.5s
# 99:	learn: 0.0150505	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522509	total: 913ms	remaining: 1m 30s
# 50:	learn: 0.0150032	total: 42.7s	remaining: 41s
# 99:	learn: 0.0094694	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0568773	total: 870ms	remaining: 1m 26s
# 50:	learn: 0.0002207	total: 42.4s	remaining: 40.7s
# 99:	learn: 0.0000852	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1518297	total: 866ms	remaining: 1m 25s
# 50:	learn: 0.0179330	total: 44.8s	remaining: 43s
# 99:	learn: 0.0119928	total: 1m 25s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1101614	total: 847ms	remaining: 1m 23s
# 50:	learn: 0.0034725	total: 42.3s	remaining: 40.6s
# 99:	learn: 0.0016370	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1520199	total: 859ms	remaining: 1m 25s
# 50:	learn: 0.0214655	total: 42.4s	remaining: 40.8s
# 99:	learn: 0.0154625	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0372713	total: 877ms	remaining: 1m 26s
# 50:	learn: 0.0009227	total: 42.5s	remaining: 40.8s
# 99:	learn: 0.0002735	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1519097	total: 909ms	remaining: 1m 30s
# 50:	learn: 0.0288659	total: 43.1s	remaining: 41.4s
# 99:	learn: 0.0208945	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0937990	total: 863ms	remaining: 1m 25s
# 50:	learn: 0.0065623	total: 42.6s	remaining: 41s
# 99:	learn: 0.0036578	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522713	total: 907ms	remaining: 1m 29s
# 50:	learn: 0.0217811	total: 43s	remaining: 41.3s
# 99:	learn: 0.0146216	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0986368	total: 831ms	remaining: 1m 22s
# 50:	learn: 0.0135164	total: 42.1s	remaining: 40.4s
# 99:	learn: 0.0087320	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1140981	total: 830ms	remaining: 1m 22s
# 50:	learn: 0.0079991	total: 43.2s	remaining: 41.5s
# 99:	learn: 0.0041473	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1516984	total: 830ms	remaining: 1m 22s
# 50:	learn: 0.0169651	total: 43.1s	remaining: 41.5s
# 99:	learn: 0.0113918	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521764	total: 867ms	remaining: 1m 25s
# 50:	learn: 0.0280932	total: 42.6s	remaining: 40.9s
# 99:	learn: 0.0202654	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1218733	total: 836ms	remaining: 1m 22s
# 50:	learn: 0.0098116	total: 42.3s	remaining: 40.7s
# 99:	learn: 0.0054800	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0394412	total: 849ms	remaining: 1m 24s
# 50:	learn: 0.0007375	total: 42.4s	remaining: 40.7s
# 99:	learn: 0.0002241	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521372	total: 850ms	remaining: 1m 24s
# 50:	learn: 0.0069990	total: 43.1s	remaining: 41.4s
# 99:	learn: 0.0036824	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1328531	total: 888ms	remaining: 1m 27s
# 50:	learn: 0.0037781	total: 42.3s	remaining: 40.6s
# 99:	learn: 0.0018067	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1132821	total: 853ms	remaining: 1m 24s
# 50:	learn: 0.0112745	total: 42s	remaining: 40.3s
# 99:	learn: 0.0067985	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1519643	total: 859ms	remaining: 1m 25s
# 50:	learn: 0.0126234	total: 41.8s	remaining: 40.2s
# 99:	learn: 0.0076801	total: 1m 21s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0725670	total: 877ms	remaining: 1m 26s
# 50:	learn: 0.0045095	total: 43.2s	remaining: 41.5s
# 99:	learn: 0.0024088	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1522418	total: 875ms	remaining: 1m 26s
# 50:	learn: 0.0226848	total: 43.4s	remaining: 41.7s
# 99:	learn: 0.0147903	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0437702	total: 821ms	remaining: 1m 21s
# 50:	learn: 0.0013096	total: 42.4s	remaining: 40.7s
# 99:	learn: 0.0004368	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0875726	total: 911ms	remaining: 1m 30s
# 50:	learn: 0.0089459	total: 42.8s	remaining: 41.2s
# 99:	learn: 0.0045685	total: 1m 23s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0589626	total: 910ms	remaining: 1m 30s
# 50:	learn: 0.0035846	total: 42s	remaining: 40.4s
# 99:	learn: 0.0015212	total: 1m 22s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1521761	total: 845ms	remaining: 1m 23s
# 50:	learn: 0.0036834	total: 43s	remaining: 41.3s
# 99:	learn: 0.0016217	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0964993	total: 949ms	remaining: 1m 33s
# 50:	learn: 0.0040161	total: 43.6s	remaining: 41.9s
# 99:	learn: 0.0019515	total: 1m 25s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0649405	total: 838ms	remaining: 1m 22s
# 50:	learn: 0.0022156	total: 43.4s	remaining: 41.7s
# 99:	learn: 0.0009195	total: 1m 25s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0867373	total: 910ms	remaining: 1m 30s
# 50:	learn: 0.0009676	total: 44.1s	remaining: 42.4s
# 99:	learn: 0.0004262	total: 1m 25s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.0346454	total: 874ms	remaining: 1m 26s
# 50:	learn: 0.0001616	total: 43.3s	remaining: 41.6s
# 99:	learn: 0.0000579	total: 1m 24s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1518519	total: 856ms	remaining: 1m 24s
# 50:	learn: 0.0256836	total: 44.3s	remaining: 42.6s
# 99:	learn: 0.0170318	total: 1m 26s	remaining: 0us
# Learning rate set to 0.477254
# 0:	learn: 0.1172600	total: 945ms	remaining: 1m 33s
# 50:	learn: 0.0185522	total: 43.8s	remaining: 42.1s
# 99:	learn: 0.0124151	total: 1m 25s	remaining: 0us
# CPU times: total: 18h 39min 16s
# Wall time: 2h 9min 28s
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('catboost',
#                  MultiOutputClassifier(estimator=<catboost.core.CatBoostClassifier object at 0x000002787FF15640>))])

# %% [markdown]
# ## Результаты

# %% [markdown]
# ### Результаты текущей обученной модели

# %% [markdown]
# #### Предсказание, оценка и сохранение результатов

# %%
try:
    os.mkdir('..\\Результаты')
    os.mkdir('..\\Результаты\\models')
    os.mkdir('..\\Результаты\\models_csv')
except:
    print('Already exists')

# %%
y_pred = pipe.predict(X_test)
estimation(y_test, y_pred, save_file=True, filename='..\\Результаты\\models_csv\\model_tfidf_catboost_ngram_1_1.csv')
joblib.dump(pipe, '..\\Результаты\\models\\model_tfidf_catboost_ngram_1_1.pkl')
# Out:
# Accuracy: 0.47447
# Hamming distance: 0.49301
# Identity (by Hamming distance): 0.99327
#
#                       precision    recall  f1-score   support
#
#              Coцсети       0.77      0.64      0.70       200
#                 Авто       0.91      0.75      0.82        28
#           Автобизнес       0.78      0.52      0.62        62
#           Белоруссия       0.81      0.84      0.83       183
#               Бизнес       0.78      0.31      0.44       200
#           Бокс и ММА       0.98      0.94      0.96       200
#          Бывший СССР       0.91      0.49      0.64       200
#                 Вещи       0.67      0.05      0.09        85
#      Вирусные ролики       0.76      0.56      0.64        95
#                Вкусы       0.00      0.00      0.00        11
#          Внешний вид       0.86      0.61      0.71       145
#              Гаджеты       0.77      0.56      0.65       200
#                Город       0.55      0.28      0.37       200
#         Госэкономика       0.68      0.38      0.48       200
#                 Дача       0.82      0.55      0.66       200
#             Движение       0.94      0.72      0.82       167
#       Деловой климат       0.59      0.17      0.26       200
#               Деньги       0.68      0.36      0.47       200
#                  Дом       0.77      0.43      0.56       200
#           Достижения       0.66      0.24      0.36       144
#                  Еда       0.56      0.31      0.40        91
#                Жизнь       0.94      0.76      0.84        67
#           Закавказье       0.91      0.86      0.88       200
#                Звери       0.72      0.56      0.63       200
#          Зимние виды       0.91      0.85      0.88       200
#                 Игры       0.98      0.94      0.96       200
#             Из жизни       0.90      0.45      0.60       200
#          Инструменты       0.74      0.40      0.52       142
#             Интернет       0.65      0.35      0.46       200
#       Интернет и СМИ       0.80      0.45      0.58       200
#            Искусство       0.79      0.63      0.70       200
#              История       0.66      0.48      0.55        69
#             Квартира       0.68      0.40      0.50       200
#    Киберпреступность       0.95      0.56      0.70        34
#                 Кино       0.86      0.65      0.74       200
#                Книги       0.80      0.70      0.75       200
#            Конфликты       0.88      0.72      0.79       200
#               Космос       0.68      0.59      0.64       200
#             Криминал       0.66      0.41      0.50       200
#                 Крым       0.87      0.69      0.77       133
#             Культура       0.79      0.32      0.46       200
#          Летние виды       0.94      0.81      0.87       200
#                 Люди       0.66      0.14      0.24       200
#                 Мемы       0.88      0.54      0.67        95
#                  Мир       0.74      0.14      0.24       200
#       Мировой бизнес       0.55      0.20      0.29       171
#               Мнения       0.80      0.45      0.57       123
#             Молдавия       0.93      0.91      0.92        88
#               Москва       0.73      0.42      0.54       200
#               Музыка       0.91      0.73      0.81       200
#                Наука       0.83      0.64      0.72       200
#      Наука и техника       0.78      0.33      0.46       200
#             Общество       0.83      0.12      0.22       200
#               Оружие       0.91      0.58      0.71       200
#                 Офис       0.71      0.31      0.43       157
#       Первая мировая       0.60      0.46      0.52        13
#             Политика       0.81      0.38      0.52       200
# Полиция и спецслужбы       0.59      0.28      0.38       200
#               Пресса       0.76      0.53      0.62       200
#    Преступная Россия       0.74      0.59      0.65        29
#         Преступность       0.76      0.39      0.51       200
#           Прибалтика       0.90      0.83      0.86       200
#         Происшествия       0.68      0.28      0.40       200
#          Путешествия       0.00      0.00      0.00        12
#              Регионы       0.55      0.19      0.28       200
#              Реклама       0.65      0.31      0.42        78
#               Россия       0.82      0.33      0.47       200
#                Рынки       0.78      0.57      0.66       200
#    Силовые структуры       0.94      0.66      0.77       200
#      Следствие и суд       0.81      0.51      0.62       200
#              События       0.64      0.29      0.40       200
#                 Софт       0.70      0.39      0.50       130
#     Социальная сфера       0.00      0.00      0.00        14
#                Спорт       0.94      0.69      0.80       200
#         Средняя Азия       0.88      0.79      0.83       200
#                Стиль       0.73      0.56      0.64       200
#           ТВ и радио       0.80      0.56      0.65       200
#                Театр       0.83      0.81      0.82       200
#              Техника       0.65      0.35      0.45       200
#               Туризм       0.00      0.00      0.00        17
#              Украина       0.90      0.71      0.79       200
#     Финансы компаний       0.50      0.06      0.11        31
#               Футбол       0.91      0.81      0.85       200
#               Хоккей       0.85      0.83      0.84       183
#             Ценности       0.62      0.13      0.22        38
#                 Часы       0.90      0.86      0.88       132
#             Экология       1.00      0.27      0.43        11
#            Экономика       0.85      0.34      0.49       200
#              Явления       0.64      0.35      0.46       200
#
#            micro avg       0.81      0.51      0.63     14178
#            macro avg       0.75      0.48      0.57     14178
#         weighted avg       0.78      0.51      0.60     14178
#          samples avg       0.49      0.51      0.50     14178
# ['D:\\netology_diplom\\final\\models_files\\model_tfidf_catboost_ngram_1_1.pkl']

# %% [markdown]
# #### Матрицы несоответствий по категориям

# %%
cm_show(y_test, 
        y_pred, 
        nrows=18, 
        ncols=5, 
        figsize_w=30, 
        figsize_h=100, 
        wspace=0.2, 
        hspace=0.4
        )
# Out:
# Время выполнения: 7.977 с

# %% [markdown]
# ### Результаты ранее обученной модели

# %% [markdown]
# #### Загрузка модели, предсказание и оценка

# %%
model_path = '..\\Результаты\\models\\model_tfidf_catboost_ngram_1_1.pkl'

model = joblib.load(model_path)
y_pred = model.predict(X_test)
metrics = estimation(y_test, y_pred)
# Out:
# Accuracy: 0.47447
# Hamming distance: 0.49301
# Identity (by Hamming distance): 0.99327
#
#                       precision    recall  f1-score   support
#
#              Coцсети       0.77      0.64      0.70       200
#                 Авто       0.91      0.75      0.82        28
#           Автобизнес       0.78      0.52      0.62        62
#           Белоруссия       0.81      0.84      0.83       183
#               Бизнес       0.78      0.31      0.44       200
#           Бокс и ММА       0.98      0.94      0.96       200
#          Бывший СССР       0.91      0.49      0.64       200
#                 Вещи       0.67      0.05      0.09        85
#      Вирусные ролики       0.76      0.56      0.64        95
#                Вкусы       0.00      0.00      0.00        11
#          Внешний вид       0.86      0.61      0.71       145
#              Гаджеты       0.77      0.56      0.65       200
#                Город       0.55      0.28      0.37       200
#         Госэкономика       0.68      0.38      0.48       200
#                 Дача       0.82      0.55      0.66       200
#             Движение       0.94      0.72      0.82       167
#       Деловой климат       0.59      0.17      0.26       200
#               Деньги       0.68      0.36      0.47       200
#                  Дом       0.77      0.43      0.56       200
#           Достижения       0.66      0.24      0.36       144
#                  Еда       0.56      0.31      0.40        91
#                Жизнь       0.94      0.76      0.84        67
#           Закавказье       0.91      0.86      0.88       200
#                Звери       0.72      0.56      0.63       200
#          Зимние виды       0.91      0.85      0.88       200
#                 Игры       0.98      0.94      0.96       200
#             Из жизни       0.90      0.45      0.60       200
#          Инструменты       0.74      0.40      0.52       142
#             Интернет       0.65      0.35      0.46       200
#       Интернет и СМИ       0.80      0.45      0.58       200
#            Искусство       0.79      0.63      0.70       200
#              История       0.66      0.48      0.55        69
#             Квартира       0.68      0.40      0.50       200
#    Киберпреступность       0.95      0.56      0.70        34
#                 Кино       0.86      0.65      0.74       200
#                Книги       0.80      0.70      0.75       200
#            Конфликты       0.88      0.72      0.79       200
#               Космос       0.68      0.59      0.64       200
#             Криминал       0.66      0.41      0.50       200
#                 Крым       0.87      0.69      0.77       133
#             Культура       0.79      0.32      0.46       200
#          Летние виды       0.94      0.81      0.87       200
#                 Люди       0.66      0.14      0.24       200
#                 Мемы       0.88      0.54      0.67        95
#                  Мир       0.74      0.14      0.24       200
#       Мировой бизнес       0.55      0.20      0.29       171
#               Мнения       0.80      0.45      0.57       123
#             Молдавия       0.93      0.91      0.92        88
#               Москва       0.73      0.42      0.54       200
#               Музыка       0.91      0.73      0.81       200
#                Наука       0.83      0.64      0.72       200
#      Наука и техника       0.78      0.33      0.46       200
#             Общество       0.83      0.12      0.22       200
#               Оружие       0.91      0.58      0.71       200
#                 Офис       0.71      0.31      0.43       157
#       Первая мировая       0.60      0.46      0.52        13
#             Политика       0.81      0.38      0.52       200
# Полиция и спецслужбы       0.59      0.28      0.38       200
#               Пресса       0.76      0.53      0.62       200
#    Преступная Россия       0.74      0.59      0.65        29
#         Преступность       0.76      0.39      0.51       200
#           Прибалтика       0.90      0.83      0.86       200
#         Происшествия       0.68      0.28      0.40       200
#          Путешествия       0.00      0.00      0.00        12
#              Регионы       0.55      0.19      0.28       200
#              Реклама       0.65      0.31      0.42        78
#               Россия       0.82      0.33      0.47       200
#                Рынки       0.78      0.57      0.66       200
#    Силовые структуры       0.94      0.66      0.77       200
#      Следствие и суд       0.81      0.51      0.62       200
#              События       0.64      0.29      0.40       200
#                 Софт       0.70      0.39      0.50       130
#     Социальная сфера       0.00      0.00      0.00        14
#                Спорт       0.94      0.69      0.80       200
#         Средняя Азия       0.88      0.79      0.83       200
#                Стиль       0.73      0.56      0.64       200
#           ТВ и радио       0.80      0.56      0.65       200
#                Театр       0.83      0.81      0.82       200
#              Техника       0.65      0.35      0.45       200
#               Туризм       0.00      0.00      0.00        17
#              Украина       0.90      0.71      0.79       200
#     Финансы компаний       0.50      0.06      0.11        31
#               Футбол       0.91      0.81      0.85       200
#               Хоккей       0.85      0.83      0.84       183
#             Ценности       0.62      0.13      0.22        38
#                 Часы       0.90      0.86      0.88       132
#             Экология       1.00      0.27      0.43        11
#            Экономика       0.85      0.34      0.49       200
#              Явления       0.64      0.35      0.46       200
#
#            micro avg       0.81      0.51      0.63     14178
#            macro avg       0.75      0.48      0.57     14178
#         weighted avg       0.78      0.51      0.60     14178
#          samples avg       0.49      0.51      0.50     14178

# %% [markdown]
# #### Матрицы несоответствий по категориям

# %%
cm_show(y_test, 
        y_pred, 
        nrows=18, 
        ncols=5, 
        figsize_w=30, 
        figsize_h=100, 
        wspace=0.2, 
        hspace=0.4
        )
# Out:
# Время выполнения: 7.939 с
